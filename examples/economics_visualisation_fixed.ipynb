# %% [markdown]
# # Prelims

# %% [markdown]
# Before running this notebook, run:
# ```bash
# mkdir -p ~/dumps
# cd ~/dumps
# python -m adapter_covid19.example basic
# python -m adapter_covid19.example no_lockdown
# python -m adapter_covid19.example slow_unlock
# python -m adapter_covid19.example slow_unlock_constrained
# ```
#
# Warning: the above takes 10GB of RAM

# %%
import sys, os
sys.path.append(os.path.abspath('../src'))

# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import pickle
import glob

# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm

# %%
# SET THESE!
data_path = os.path.expanduser('~/dumps')
start_date = pd.to_datetime("2020-03-13") # date when simulation starts, i.e. time == 0
assert len(data_path) > 0, "Set data path!"

# %%
# %matplotlib inline

# %%
from adapter_covid19.simulator import *
from adapter_covid19.scenarios import *
from adapter_covid19.metrics import *

# %%
import matplotlib
matplotlib.rc('font', size=18)

# %% [markdown]
# # Multiple Scenarios

# %%
scenario_files = [
    os.path.join(data_path,f"{x}.pkl")
    for x in [
        'scenario_no_lockdown', 'scenario_basic', 'scenario_slow_unlock', 'scenario_slow_unlock_constrained'
    ]]

# %%
summary_dfs = {}

# %%
def load_scenario(scenario_file):
    global summary_dfs
    try:
        with open(scenario_file,"rb") as f:
            name,scenario,(econ,states) = pickle.load(f)
        summary_dfs[name] = summarize_one_scenario(econ,states,end_time=scenario.simulation_end_time,start_date=start_date)
        del states
    except:
        print(f"error loading {scenario_file}")

# %%
for scenario_file in tqdm(scenario_files):
    load_scenario(scenario_file)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 100%|██████████| 4/4 [00:00<00:00, 14500.62it/s]
# error loading /home/ubuntu/dumps/scenario_no_lockdown.pkl
# error loading /home/ubuntu/dumps/scenario_basic.pkl
# error loading /home/ubuntu/dumps/scenario_slow_unlock.pkl
# error loading /home/ubuntu/dumps/scenario_slow_unlock_constrained.pkl

# %%
if summary_dfs:
    metrics_scenarios(summary_dfs)
else:
    print(f'No scenario data loaded from {data_path}; skipping metrics.')
# Out:
# No scenario data loaded from /home/ubuntu/dumps; skipping metrics.

# %%
if summary_dfs:
    plot_scenarios(summary_dfs, end_time=202)
else:
    print(f'No scenario data loaded from {data_path}; skipping plots.')
# Out:
# No scenario data loaded from /home/ubuntu/dumps; skipping plots.
